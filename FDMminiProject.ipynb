# %% [markdown]
# <a href="https://colab.research.google.com/github/IT22253880/Mad-Lab-4/blob/main/FDMminiProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **FDM** **mini** **project**
#
# ---
#
#
# ### Automobile Loan Prediction

# %% [markdown]
# > Import packages

# %%
import pandas as pd

# %% [markdown]
# > Data collection

# %%
dataset = pd.read_csv('/FDM_miniproject/Automobile_Loan.csv')
# Out:
# <ipython-input-3-a2da671212ea>:1: DtypeWarning: Columns (1,7,8,16,17,18,19,20,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv('/FDM_miniproject/Automobile_Loan.csv')

# %%
dataset.head()
# Out:
#          ID Client_Income  Car_Owned  Bike_Owned  Active_Loan  House_Own  \
# 0  12142509          6750        0.0         0.0          1.0        0.0
# 1  12138936         20250        1.0         0.0          1.0        NaN
# 2  12181264         18000        0.0         0.0          1.0        0.0
# 3  12188929         15750        0.0         0.0          1.0        1.0
# 4  12133385         33750        1.0         0.0          1.0        0.0
#
#    Child_Count Credit_Amount Loan_Annuity Accompany_Client  ...  \
# 0          0.0      61190.55      3416.85            Alone  ...
# 1          0.0         15282      1826.55            Alone  ...
# 2          1.0      59527.35       2788.2            Alone  ...
# 3          0.0       53870.4      2295.45            Alone  ...
# 4          2.0      133988.4      3547.35            Alone  ...
#
#   Client_Permanent_Match_Tag Client_Contact_Work_Tag       Type_Organization  \
# ...
